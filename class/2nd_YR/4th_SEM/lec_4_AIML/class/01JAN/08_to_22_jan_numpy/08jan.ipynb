# %%
print('helo')
print('CV')

# %%
print('helo',end=" ")
print('CV')
# Out:
# helo CV

# %%
a=465
print(type(a))
# Out:
# <class 'int'>

# %%
a='10'
print(type(a))
a=10
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.7 MB 1.4 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/10.7 MB 825.8 kB/s eta 0:00:13
#    ---------------------------------------- 0.1/10.7 MB 655.4 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/10.7 MB 547.6 kB/s eta 0:00:20
#     --------------------------------------- 0.1/10.7 MB 655.8 kB/s eta 0:00:17
#     --------------------------------------- 0.2/10.7 MB 573.4 kB/s eta 0:00:19
#     --------------------------------------- 0.2/10.7 MB 655.6 kB/s eta 0:00:16
#     --------------------------------------- 0.3/10.7 MB 716.5 kB/s eta 0:00:15
#    - -------------------------------------- 0.3/10.7 MB 656.7 kB/s eta 0:00:16
#    - -------------------------------------- 0.3/10.7 MB 656.7 kB/s eta 0:00:16
#    - -------------------------------------- 0.3/10.7 MB 634.7 kB/s eta 0:00:17
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      --------- --------------------------- 41.0/160.4 kB 960.0 kB/s eta 0:00:01
#      -------------------------- ----------- 112.6/160.4 kB 1.3 MB/s eta 0:00:01
#      --------------------------------- ---- 143.4/160.4 kB 1.4 MB/s eta 0:00:01
#      --------------------------------- ---- 143.4/160.4 kB 1.4 MB/s eta 0:00:01
#      ------------------------------------ 160.4/160.4 kB 798.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB 1.3 MB/s eta 0:00:06
#    ---------------------------------------- 0.0/7.6 MB 1.3 MB/s eta 0:00:06
#    ---------------------------------------- 0.0/7.6 MB 1.3 MB/s eta 0:00:06
#     --------------------------------------- 0.1/7.6 MB 587.0 kB/s eta 0:00:13
#     --------------------------------------- 0.1/7.6 MB 599.1 kB/s eta 0:00:13
# ...

# %%
pip install Seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.8 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.8 kB 991.0 kB/s eta 0:00:01
#    --------------- ------------------------ 112.6/294.8 kB 1.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 163.8/294.8 kB 1.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 174.1/294.8 kB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 276.5/294.8 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 294.8/294.8 kB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
