# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset("tips")
sns.swarmplot(x="total_bill",data=data)
plt.xticks(rotation=-45,size=10)
plt.show()

# %%
data=sns.load_dataset("tips")
sns.swarmplot(x="total_bill",y="day",data=data)
plt.show()

# %%
data=sns.load_dataset("tips")
sns.violinplot(x="total_bill",y="day",data=data)
plt.show()

# %%
data=sns.load_dataset("tips")
sns.swarmplot(y="total_bill",x="day",data=data)
plt.show()

# %%
data=sns.load_dataset("tips")
sns.swarmplot(y="total_bill",x="day",data=data,size=6)
plt.show()

# %%
data=sns.load_dataset("tips")
sns.swarmplot(y="total_bill",x="day",data=data,size=6,hue="size")
plt.show()

# %%
data=sns.load_dataset("tips")
sns.swarmplot(x="total_bill",y="day",data=data,size=6,hue="size",orient="h")
plt.show()

# %%
data=sns.load_dataset("tips")
sns.swarmplot(y="total_bill",x="day",data=data,size=6,hue="size",orient="v")
plt.show()

# %%
data=sns.load_dataset("tips")
sns.swarmplot(y="total_bill",x="day",data=data,linewidth=9)
plt.show()
# Out:
# c:\Users\manu1\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3398: UserWarning: 32.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\manu1\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3398: UserWarning: 34.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\manu1\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3398: UserWarning: 28.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\manu1\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3398: UserWarning: 38.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
data=sns.load_dataset("tips")
sns.swarmplot(y="total_bill",x="day",data=data,linewidth=9,palette="Set2")
plt.show()
# Out:
# C:\Users\manu1\AppData\Local\Temp\ipykernel_19872\2257373371.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(y="total_bill",x="day",data=data,linewidth=9,palette="Set2")
# c:\Users\manu1\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3398: UserWarning: 32.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\manu1\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3398: UserWarning: 34.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
data=sns.load_dataset("tips")
sns.swarmplot(y="total_bill",x="day",data=data,palette="Set2",marker="D",edgecolor="gray",alpha=0.7)
plt.show()
# Out:
# C:\Users\manu1\AppData\Local\Temp\ipykernel_19872\2495329024.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(y="total_bill",x="day",data=data,palette="Set2",marker="D",edgecolor="gray",alpha=0.7)
# C:\Users\manu1\AppData\Local\Temp\ipykernel_19872\2495329024.py:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.swarmplot(y="total_bill",x="day",data=data,palette="Set2",marker="D",edgecolor="gray",alpha=0.7)

# %%
data=sns.load_dataset("tips")
sns.swarmplot(y="total_bill",x="day",data=data,palette="Set2",marker="D",edgecolor="gray",alpha=0.7)
plt.show()
# Out:
# C:\Users\manu1\AppData\Local\Temp\ipykernel_19872\2495329024.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(y="total_bill",x="day",data=data,palette="Set2",marker="D",edgecolor="gray",alpha=0.7)
# C:\Users\manu1\AppData\Local\Temp\ipykernel_19872\2495329024.py:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.swarmplot(y="total_bill",x="day",data=data,palette="Set2",marker="D",edgecolor="gray",alpha=0.7)

# %%
data=sns.load_dataset("tips")
sns.violinplot(y="total_bill",x="day",data=data,palette="Set3",alpha=0.5,width=1,orient="v",hue="smoker")
plt.show()

# %%
d=np.random.randint(low=1,high=100,size=(10,10))
print(d)
hm=sns.heatmap(data=d,annot=True)#annot=True enables values
# Out:
# [[38 33 88 42  8 48 48 44 10 70]
#  [60 94 71 83 90 72 17 65 80  8]
#  [49 84 17 78 25 79 97 99 52 40]
#  [30 69  6 23 53 82 27 17 25 63]
#  [ 7 43 38 11 41 70 77 17 61 89]
#  [68 85 87 77 10 32 47 14 60 22]
#  [47 17 69 68 70 69  3 96 45 27]
#  [61 28 48 84 49 44 24 79 99 75]
#  [71 33  2 22 17 25  7 32 42 54]
#  [28 15 81 47 24 37 21 26 62 39]]
