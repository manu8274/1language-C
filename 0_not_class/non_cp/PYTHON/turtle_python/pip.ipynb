# %%
pip install pythonturtle
# Out:
# ...
#      ---------------------------------------- 0.0/518.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/518.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/518.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/518.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/518.4 kB ? eta -:--:--
#       --------------------------------------- 10.2/518.4 kB ? eta -:--:--
#       --------------------------------------- 10.2/518.4 kB ? eta -:--:--
#       --------------------------------------- 10.2/518.4 kB ? eta -:--:--
#      -- ---------------------------------- 30.7/518.4 kB 163.8 kB/s eta 0:00:03
#      -- ---------------------------------- 30.7/518.4 kB 163.8 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/518.4 kB 130.7 kB/s eta 0:00:04
#      -- ---------------------------------- 41.0/518.4 kB 130.7 kB/s eta 0:00:04
# ...

# %%
from turtle import *
begin_fill()
for i in range(4):
    forward(100)
    left(90)
end_fill()
done()
