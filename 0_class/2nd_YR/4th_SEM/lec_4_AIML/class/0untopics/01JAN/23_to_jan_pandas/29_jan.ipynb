# %%
import pandas as pd

# %%
data=pd.read_csv('big_mart_sales.csv')
print(data[["Item_Fat_Content","Item_MRP"]].to_string())
# Out:
#      Item_Fat_Content  Item_MRP
# 0             Low Fat  249.8092
# 1             Regular   48.2692
# 2             Low Fat  141.6180
# 3             Regular  182.0950
# 4             Low Fat   53.8614
# 5             Regular   51.4008
# 6             Regular   57.6588
# 7             Low Fat  107.7622
# 8             Regular   96.9726
# 9             Regular  187.8214
# 10            Low Fat   45.5402
# 11            Regular  144.1102
# 12            Regular  145.4786
# 13            Regular  119.6782
# 14            Low Fat  196.4426
# 15            Regular   56.3614
# 16            Low Fat  115.3492
# 17            Regular   54.3614
# 18            Low Fat  113.2834
# 19            Low Fat  230.5352
# 20            Regular  250.8724
# 21            Regular  144.5444
# 22            Low Fat  196.5084
# 23            Low Fat  107.6938
# 24            Regular  165.0210
# 25            Low Fat   45.9060
# 26            Regular   42.3112
# 27            low fat   39.1164
# ...

# %%
import numpy as np

# %%
print(np.mean(np.arange(10).reshape(2, -1)))
# Out:
# 4.5

# %%
arr1=np.array([1,2,3,4])
print(np.percentile(arr1,50))
# Out:
# 2.5

# %%
print(np.dot(np.array([1, 2]), np.array([3, 4])))
# Out:
# 11

# %%
ar=np.random.uniform(1,11,(2,2))
print(ar)
# Out:
# [[ 8.11296668  2.42797474]
#  [10.68450449 10.80864727]]
